# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import json
import urllib.request
from bs4 import BeautifulSoup
import pandas as pd

# %%
# %cd drive/MyDrive/github/ml-esg-3
# Out:
# /content/drive/MyDrive/github/ml-esg-3

# %%
COLUMNS = ["url", "title", "content", "impact_length_idx", "language"]

# %% [markdown]
# # English Dataset

# %%
eng_path = "dataset/ML-ESG-3_Trainset_English.json"
with open(eng_path) as f:
  eng_json = json.load(fp=f)
eng_df = pd.DataFrame.from_dict(eng_json)

# %%
eng_df.head(1)
# Out:
#                                                  URL  \
# 0  https://www.esgtoday.com/arabesque-ai-appoints...
#
#                                           news_title  \
# 0  Arabesque AI Appoints Carolina Minio Paluello ...
#
#                                         news_content impact_level  \
# 0  ESG-focused financial technology company Arabe...          low
#
#   impact_length
# 0  2 to 5 years

# %%
print(len(eng_df))
# Out:
# 545

# %%
eng_df.groupby("impact_level")["URL"].count()
# Out:
# impact_level
# high      196
# low       106
# medium    243
# Name: URL, dtype: int64

# %%
eng_df.groupby("impact_length")["URL"].count()
# Out:
# impact_length
# 2 to 5 years         198
# Less than 2 years     82
# More than 5 years    265
# Name: URL, dtype: int64

# %%
eng_df = eng_df.rename(columns={"URL": "url",
                                "news_title": "title",
                                "news_content": "content"})

label_dict = {
    "Less than 2 years": 0,
    "2 to 5 years": 1,
    "More than 5 years": 2
}
eng_df["impact_length_idx"] = eng_df["impact_length"].map(label_dict)

eng_df["language"] = "English"
eng_df = eng_df[COLUMNS]

# %%
eng_df.head(1)
# Out:
#                                                  url  \
# 0  https://www.esgtoday.com/arabesque-ai-appoints...
#
#                                                title  \
# 0  Arabesque AI Appoints Carolina Minio Paluello ...
#
#                                              content  impact_length_idx  \
# 0  ESG-focused financial technology company Arabe...                  1
#
#   language
# 0  English

# %% [markdown]
# # Chinese Dataset

# %%
chn_path = "dataset/ML-ESG-3_Trainset_Chinese.json"

# %%
with open(chn_path) as f:
  chn_json = json.load(f)
chn_df = pd.DataFrame.from_dict(chn_json)

# %%
chn_df.head(1)
# Out:
#      pk                                                URL  \
# 0  1421  https://esg.businesstoday.com.tw/article/categ...
#
#                    News_Headline Impact_Duration
# 0  老闆本人就是打卡機？比爾蓋茲背下員工車牌，計算每人工作時數            [>5]

# %%
chn_df["Impact_Duration"] = chn_df["Impact_Duration"].apply(lambda x: x[0])

# %%
chn_df.groupby("Impact_Duration")["URL"].count()
# Out:
# Impact_Duration
# 2~5                      62
# <2                       87
# >5                      203
# NotRelatedtoCompany     593
# NotRelatedtoESGTopic     50
# Name: URL, dtype: int64

# %%
chn_df = chn_df.rename(columns={
    "URL": "url",
    "News_Headline": "title",
})
label_dict = {
    "<2": 0,
    "2~5": 1,
    ">5": 2,
    "NotRelatedtoCompany": None,
    "NotRelatedtoESGTopic": None
}
chn_df["impact_length_idx"] = chn_df["Impact_Duration"].map(label_dict)
chn_df = chn_df[chn_df["impact_length_idx"].notna()]
chn_df["language"] = "Chinese"

# %%
### TODO: load content from url
def parse_content(link):
  response = urllib.request.urlopen(link)
  web_content = response.read()
  soup = BeautifulSoup(web_content, 'html.parser')

  main_content_div = soup.find('div', class_='content_bottom')
  main_content_text = main_content_div.get_text(separator='\n', strip=True)

  cut_off_point = main_content_text.find("日期：")
  if cut_off_point != -1:
      main_content_text = main_content_text[cut_off_point:]

  cut_off_point = main_content_text.find("延伸閱讀")
  if cut_off_point != -1:
      main_content_text = main_content_text[:cut_off_point]
  return main_content_text

chn_df["content"] = chn_df["url"].apply(parse_content)

# %%
chn_df = chn_df[COLUMNS]

# %%
chn_df.head(1)
# Out:
#                                                  url  \
# 0  https://esg.businesstoday.com.tw/article/categ...
#
#                            title  \
# 0  老闆本人就是打卡機？比爾蓋茲背下員工車牌，計算每人工作時數
#
#                                              content  impact_length_idx  \
# 0  日期：\n2022-01-04\n工作與生活的平衡在現代是所有員工流行且追求的工作模式，但對...                2.0
#
#   language
# 0  Chinese

# %% [markdown]
# # French Dataset

# %%
fr_path = "dataset/ML-ESG-3_Trainset_French.json"
with open(fr_path) as f:
  fr_json = json.load(fp=f)
fr_df = pd.DataFrame.from_dict(fr_json)

# %%
fr_df.head(1)
# Out:
#                                                  URL  \
# 0  https://www.novethic.fr/actualite/energie/tran...
#
#                                           news_title  \
# 0  Interdiction à la location des passoires therm...
#
#                                         news_content impact_level  \
# 0  Depuis le 1er janvier, les passoires thermique...          low
#
#        impact_length
# 0  More than 5 years

# %%
print(len(fr_df))
# Out:
# 661

# %%
fr_df.groupby("impact_length")["URL"].count()
# Out:
# impact_length
# 2 to 5 years         231
# Less than 2 years    131
# More than 5 years    299
# Name: URL, dtype: int64

# %%
fr_df = fr_df.rename(columns={"URL": "url",
                              "news_title": "title",
                              "news_content": "content"})

label_dict = {
    "Less than 2 years": 0,
    "2 to 5 years": 1,
    "More than 5 years": 2
}
fr_df["impact_length_idx"] = fr_df["impact_length"].map(label_dict)

fr_df["language"] = "French"
fr_df = fr_df[COLUMNS]

# %%
fr_df.head(1)
# Out:
#                                                  url  \
# 0  https://www.novethic.fr/actualite/energie/tran...
#
#                                                title  \
# 0  Interdiction à la location des passoires therm...
#
#                                              content  impact_length_idx  \
# 0  Depuis le 1er janvier, les passoires thermique...                  2
#
#   language
# 0   French

# %% [markdown]
# # Japanese Dataset

# %%
jp_path = "dataset/ML-ESG-3_Trainset_Japanese.json"
with open(jp_path) as f:
  jp_json = json.load(fp=f)
jp_df = pd.DataFrame.from_dict(jp_json)

# %%
jp_df.head(1)
# Out:
#          ID                                               Text Relevancy  \
# 0  237672_6  「環境レポーティング」、「事業における環境効率」など環境分野に関する取り組みについて高い評価...  Relevant
#
#         ESG_type  Impact_type Impact_duration
# 0  Environmental  Opportunity  within_2_years

# %%
print(len(jp_df))
# Out:
# 53

# %%
jp_df.groupby("Impact_duration")["ID"].count()
# Out:
# Impact_duration
#                           3
# between_2_and_5_years     8
# longer_than_5_years      15
# within_2_years           27
# Name: ID, dtype: int64

# %%
jp_df.groupby("Relevancy")["ID"].count()
# Out:
# Relevancy
# Irrelevant     3
# Relevant      50
# Name: ID, dtype: int64

# %%
# Ignore JP dataset due to small size

# %% [markdown]
# # Korean Dataset

# %%
kr_path = "dataset/ML-ESG-3_Trainset_Korean.json"
with open(kr_path) as f:
  kr_json = json.load(fp=f)
kr_df = pd.DataFrame.from_dict(kr_json)

# %%
kr_df.head(1)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
#
#                                                  url category  \
# 0  https://www.esgeconomy.com/news/articleView.ht...   지속가능경제
#
#                           title  \
# 0  액화수소 시대 열린다...연 4만톤 설비 연내 가동
#
#                                              content  impact_type  \
# 0  연내에 두산애너빌리티와 SK E&S, 효성중공업의 액화수소 플랜트가 준공돼 연간 최...  opportunity
#
#   impact_duration
# 0    2 to 5 years

# %%
print(len(kr_df))
# Out:
# 800

# %%
kr_df.groupby("impact_duration")["url"].count()
# Out:
# impact_duration
# 2 to 5 years         142
# less than 2 years    446
# more than 5 years    212
# Name: url, dtype: int64

# %%
kr_df.groupby("impact_type")["url"].count()
# Out:
# impact_type
# cannot distinguish    109
# opportunity           462
# risk                  229
# Name: url, dtype: int64

# %%
label_dict = {
    "less than 2 years": 0,
    "2 to 5 years": 1,
    "more than 5 years": 2
}
kr_df["impact_length_idx"] = kr_df["impact_duration"].map(label_dict)
kr_df["language"] = "Korean"
kr_df = kr_df[COLUMNS]

# %%
kr_df.head(1)
# Out:
#                                                  url  \
# 0  https://www.esgeconomy.com/news/articleView.ht...
#
#                           title  \
# 0  액화수소 시대 열린다...연 4만톤 설비 연내 가동
#
#                                              content  impact_length_idx  \
# 0  연내에 두산애너빌리티와 SK E&S, 효성중공업의 액화수소 플랜트가 준공돼 연간 최...                  1
#
#   language
# 0   Korean

# %% [markdown]
# # Data Aggregation

# %%
df = pd.concat([eng_df, chn_df, fr_df, kr_df], ignore_index=True)

# %%
df.groupby("language").count()
# Out:
#           url  title  content  impact_length_idx
# language
# Chinese   352    352      352                352
# English   545    545      545                545
# French    661    661      661                661
# Korean    800    800      800                800

# %%
df.groupby("impact_length_idx").count()
# Out:
#                    url  title  content  language
# impact_length_idx
# 0.0                746    746      746       746
# 1.0                633    633      633       633
# 2.0                979    979      979       979

# %%
print(len(df))
# Out:
# 2358

# %%
df.to_parquet("dataset/train_df.parquet")
